# %%
# assignment for python
# 1. Write a while loop that prints the numbers 1 to 10.
# 2. Write a while loop that calculates the sum of the numbers from 1 to 100.
# 3. Write a while loop that prints the multiplication table of 5 (from 5x1 to 5x10).


# supposed we have a list of marks obtained by students in an exam
marks = [85, 90, 78, 92, 88, 76, 95, 89, 84]
# Write a for loop to calculate and print the average mark.
