# %%
# how to declare a variable in python

x = 2
y = 3
print(x + y)


# simple example 
age = 24

# if age >= 18: --> eligible to vote
if age >= 18:
    print("eligible to vote")
else:
    print("not eligible to vote")
# Out:
# 5
# eligible to vote

# %%
age = '18'
type(age)  # str

# what will be the age after 5 years

age + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 6
#       2 type(age)  # str
#       4 # what will be the age after 5 years
# ----> 6 age + 5
#
# TypeError: can only concatenate str (not "int") to str

# %%
salary = '1231.12'
type(salary)  # float

# lets add
18 + salary
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 5
#       2 type(salary)  # float
#       4 # lets add
# ----> 5 18 + salary
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
isVotreEligible = True
print(isVotreEligible)
# Out:
# True

# %%
age = '18'
type(age)  # str

# what will be the age after 5 years

age + 5



# here you can see that age is a string and 5 is an integer
# so python will not be able to add these two different data types
# and it will throw an error
# TypeError: can only concatenate str (not "int") to str
# typcasting


# lets convert integer to float
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 6
#       2 type(age)  # str
#       4 # what will be the age after 5 years
# ----> 6 age + 5
#      10 # here you can see that age is a string and 5 is an integer
#      11 # so python will not be able to add these two different data types
#      12 # and it will throw an error
#    (...)     16
#      17 # lets convert integer to float
#
# TypeError: can only concatenate str (not "int") to str

# %%
salary = 12000
# before typcasting
type(salary)  # int
updated_salary = float(salary)
type(updated_salary)  # float
# Out:
# float

# %%
age = '18'
type(age)  # str

# what will be the age after 5 years

age = int(age)
age + 5
# Out:
# 23

# %%
test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 test
#
# NameError: name 'test' is not defined

# %%
blog = "Data Science Everything"


type(blog)  # str
# Out:
# str

# %%
# if you have blog with more then 1 line then use triple quotes
blog = """Data Science Everything
is a blog which covers all the topics related to data science.
From python programming to machine learning and deep learning.
It also covers data visualization and data analysis."""

type(blog)  # str
# Out:
# str

# %%
# use backslash for new line in single line string
blog = "Data Science Everything \nis a blog which covers all the topics related to data science.\nFrom python programming to machine learning and deep learning.\nIt also covers data visualization and data analysis."
