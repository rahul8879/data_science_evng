# %% [markdown]
# # Python if ... else Statement

# %% [markdown]
# The **if…elif…else** statement is used in Python for decision making.

# %% [markdown]
# # if statement syntax

# %% [markdown]
#     if test expression:
#
#         statement(s)

# %% [markdown]
# The program evaluates the test expression and will execute statement(s) only if the text expression is True.
#
# If the text expression is False, the statement(s) is not executed.

# %% [markdown]
# Python interprets non-zero values as True. None and 0 are interpreted as False.

# %% [markdown]
# # Flow Chart

# %% [markdown]
# ![title](Python_if_statement.jpg)

# %%
voted_or_not = True
iseligible   = False
if iseligible or voted_or_not:
    print('hell')
    print('inside the if block')

else:
    print(' I am inside else part')
# Out:
# hell
# inside the if block

# %%
# lets suppose I want to write more complex if else ( nested if else)


if True:
    if False:
        print('hello')
    else: 
        print('in first block of if')
    
print('done')
# Out:
# in first block of if
# done

# %% [markdown]
# # Example

# %%
adhar_card = input('Enter the adhar card nuumber: ')


if False:
    print('I am in if block')
else:
    print('I am inside else block')
# Out:
# I am inside else block

# %%
adhar_card = input('Enter the adhar card nuumber: ')

# %%
adhar_card
# Out:
# '122424234234234'

# %%
lg_adhar = len(adhar_card)
lg_adhar
# Out:
# 15

# %%
test_value = []

# %%
if lg_adhar<15:
    print('Please check your adhar number')
else:
    print('Everything is perfect')
# Out:
# Everything is perfect

# %%
num = 10

if num>0:
    print("Number is positive")
print("This will print always")      #This print statement always print

#change number
# Out:
# Number is positive
# This will print always

# %% [markdown]
# # if ... else Statement

# %% [markdown]
# # Syntax:

# %% [markdown]
#     if test expression:
#
#         Body of if
#
#     else:
#
#         Body of else

# %% [markdown]
# # Flow Chart

# %% [markdown]
# ![title](Python_if_else_statement.jpg)

# %% [markdown]
# # Example

# %%
num = 6
if num > 0:
    if num <5:
        print('less then 5')
    elif num<2:
        print('xyz')
    else:
        print('test')  
        
    print("Positive number")
else:
    print("Negative Number")
# Out:
# test
# Positive number

# %% [markdown]
# # if...elif...else Statement

# %% [markdown]
# # Syntax:

# %% [markdown]
#     if test expression:
#
#         Body of if
#     elif test expression:
#
#         Body of elif
#     else:
#
#         Body of else

# %% [markdown]
# # Flow Chart

# %% [markdown]
# ![title](Python_if_elif_else_statement.jpg)

# %% [markdown]
# # Example:

# %%
num = 0

if num > 0:
    print("Positive number")
elif num == 0:
    print("ZERO")
    
elif num ==-1:
    print('found')
else:
    print("Negative Number")
# Out:
# ZERO

# %% [markdown]
# # Nested if Statements

# %% [markdown]
# We can have a if...elif...else statement inside another if...elif...else statement. This is called nesting in computer programming.

# %% [markdown]
# # Example:

# %%
num = 10.5

if num >= 0:
    if num == 0:
        print("Zero")
    else:
        print("Positive number")
else:
    print("Negative Number")
# Out:
# Positive number

# %% [markdown]
# # Python program to find the largest element among three Numbers

# %%
num1 = 10
num2 = 50
num3 = 15

if (num1 >= num2) and (num1 >= num3):           #logical operator   and
    largest = num1
elif (num2 >= num1) and (num2 >= num3):
    largest = num2
else:
    largest = num3
print("Largest element among three numbers is: {}".format(largest))
# Out:
# Largest element among three numbers is: 50
