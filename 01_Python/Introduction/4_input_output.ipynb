# %% [markdown]
# # Python Input and Output

# %% [markdown]
# # Python Output

# %% [markdown]
# We use the print() function to output data to the standard output device

# %%
print("Hello World")
# Out:
# Hello World

# %%
a = 10
print("The value of a is", a) #python 3
# print "The value of a is " + str(a)
# Out:
# The value of a is 10

# %% [markdown]
# # Output Formatting

# %%
a = 10; b = 20 #multiple statements in single line.
print('the value of a and b is ',a,b)
# Out:
# the value of a and b is  10 20

# %%
print('The value of a is {1} and b {0} '.format(a,b))
# Out:
# The value of a is 20 and b 10

# %%
a = 10; b = 20 #multiple statements in single line.
c= 15
print("The value of a is {1} , b is {0} and c is {2}".format(a, b,c))    #default
# Out:
# The value of a is 20 , b is 10 and c is 15

# %%
a = 10; b = 20  #multiple statements in single line

print("The value of b is {1} and a is {0}".format(a, b)) #specify position of arguments
# Out:
# The value of b is 20 and a is 10

# %%
#we can use keyword arguments to format the string
print("Hello {name}, {greeting}".format(name="satish", greeting="Good Morning"))
# Out:
# Hello satish, Good Morning

# %%
#we can combine positional arguments with keyword arguments
print('The story of {0}, {1}, and {other}'.format('Bill', 'Manfred',
                                                       other='Georg'))
# Out:
# The story of Bill, Manfred, and Georg

# %% [markdown]
# # Python Input

# %% [markdown]
# want to take the input from the user. In Python, we have the input() function to allow this.

# %%
age = input("please enter your age here: ")
# print num
print('The value of age is {} and type is {}'.format(age,type(age)))

if int(age)>18:
    print(' You are eligible for voting')
# Out:
# The value of age is 24 and type is <class 'str'>
#  You are eligible for voting

# %%
# Out:
# str

# %%
# lets I will ask user to enter his ssn number
# if ssn number is less then 14 then raise the issue - or say check your ssn numner
ssn = input('Enter the ssn number')

# %%
len(ssn)
# Out:
# 14

# %%
if len(ssn)==14:
    print(' You are ok !!')
# Out:
#  You are ok !!
